# %%
#image_2_encoding={}
import nbimporter
from encoding_generator import encoding_generator
# Out:
# Importing Jupyter notebook from encoding_generator.ipynb
# C:\Users\HP\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def insert_encoding_to_dict(name):
    a=[]
    print("in insert enco to dict")
    enco=encoding_generator(name)
    print("writing_values")
    #image_2_encoding[name]=enco
    a.append(enco)
    print("values_written")
    print(a)

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bca0e2660b9f> in <module>()
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
print(enco)
# Out:
# [[ 0.07617509  0.06632175  0.02958887  0.0163282   0.08563155  0.21647723
#    0.14861494 -0.06166296  0.01584402 -0.18755127 -0.02561116  0.01909122
#    0.01972013 -0.06966203  0.03251344 -0.11741949 -0.10499711 -0.06142489
#   -0.14832848  0.06012562  0.02200322  0.051209   -0.09016812  0.05523757
#   -0.03592342 -0.10085675 -0.18944858 -0.07516687 -0.02467894  0.03863517
#    0.07097463  0.04835912 -0.155389    0.08748917  0.08309049  0.06157924
#    0.03711933 -0.00630411 -0.042565   -0.05167533  0.18241967 -0.02845924
#   -0.00653027 -0.04871712 -0.06676046  0.05290483  0.04508397  0.04654931
#   -0.12681088  0.03691245 -0.13926896 -0.09635372  0.08329132  0.00542504
#    0.07387484  0.03578322 -0.1812274   0.17240873 -0.09696488 -0.05270428
#   -0.09282927  0.17092654  0.14000334 -0.18947762  0.05119378  0.12380239
#    0.10160996 -0.02818121 -0.14782326 -0.03196465  0.04979812  0.02342045
#    0.02778701  0.06201109  0.03809779  0.07014135 -0.02361233 -0.12123352
# ...

# %%
print(enco)
# Out:
# [[ 0.07617509  0.06632175  0.02958887  0.0163282   0.08563155  0.21647723
#    0.14861494 -0.06166296  0.01584402 -0.18755127 -0.02561116  0.01909122
#    0.01972013 -0.06966203  0.03251344 -0.11741949 -0.10499711 -0.06142489
#   -0.14832848  0.06012562  0.02200322  0.051209   -0.09016812  0.05523757
#   -0.03592342 -0.10085675 -0.18944858 -0.07516687 -0.02467894  0.03863517
#    0.07097463  0.04835912 -0.155389    0.08748917  0.08309049  0.06157924
#    0.03711933 -0.00630411 -0.042565   -0.05167533  0.18241967 -0.02845924
#   -0.00653027 -0.04871712 -0.06676046  0.05290483  0.04508397  0.04654931
#   -0.12681088  0.03691245 -0.13926896 -0.09635372  0.08329132  0.00542504
#    0.07387484  0.03578322 -0.1812274   0.17240873 -0.09696488 -0.05270428
#   -0.09282927  0.17092654  0.14000334 -0.18947762  0.05119378  0.12380239
#    0.10160996 -0.02818121 -0.14782326 -0.03196465  0.04979812  0.02342045
#    0.02778701  0.06201109  0.03809779  0.07014135 -0.02361233 -0.12123352
# ...
