# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade=cv2.CascadeClassifier('C:\\Users\\HP\\Desktop\\face_recognition\\haarcascade_frontalface_default.xml')
eye_cascade=cv2.CascadeClassifier('C:\\Users\\HP\\Desktop\\face_recognition\\haarcascade_eye.xml')

# %%
import numpy as np
import cv2

img = cv2.imread('C:\\Users\\HP\\Desktop\\face_recognition\\ping.JPG')
img.shape
# Out:
# (6000, 4000, 3)

# %%
#img=cv2.resize(img,(256,256))

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[118, 120, 117, ..., 160, 162, 163],
#        [115, 119, 118, ..., 164, 164, 165],
#        [116, 116, 115, ..., 163, 161, 164],
#        ...,
#        [132, 134, 136, ..., 107, 106, 119],
#        [134, 135, 137, ..., 109, 112, 114],
#        [139, 132, 138, ..., 113, 115, 114]], dtype=uint8)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
start_row,start_col,end_row,end_col=faces[0]
# Out:
# [[1444 1107 1260 1260]]

# %%
print(start_row)
print(start_col)
print(end_row)
print(end_col)
# Out:
# 1444
# 1107
# 1260
# 1260

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

# %%
path='C:\\Users\\HP\\Desktop\\face_recognition\\cropped_image_database'

# %%
cropped=gray[start_col:start_col+end_col,start_row:start_row+end_row]
img_name = "opencv_frame_{}.png".format(input())
cv2.imwrite(img_name, cropped)
print("{} written!".format(img_name))
# Out:
# pin2
# opencv_frame_pin2.png written!

# %%
cropped=cv2.resize(cropped,(256,256))

# %%
plt.imshow(cropped)

# %%
cropped.shape
# Out:
# (256, 256)

# %%
path='C:\\Users\\HP\\Desktop\\face_recognition\\cropped_image_database'
plt.savefig('cropped')

# %%
cv2.imshow('img',gray)
cv2.waitKey(0)
cv2.imshow('cropped',cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()
